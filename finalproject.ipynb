# %%
#Project ONE
# This is simplest Student data management program in python
# Create class "Student"
# Create a list to add Students
class studentmanagementsystem:
    def __init__(self,firstname,middlename,surname,gender,dob,address,stateoforigin,seatnumber):
        self.firstname =  firstname
        self.middlename =  middlename
        self.surname =  surname
        self.gender =  gender
        self.dob =  dob
        self.address =  address
        self.stateoforigin =  stateoforigin
        self.seatnumber =  seatnumber
    def accept(self,FIRSTNAME,MIDDLENAME,SURNAME,GENDER,DOB,ADDRESS,STATEOFORIGIN,SEATNUMBER):
        ob= studentmanagementsystem(FIRSTNAME,MIDDLENAME,SURNAME,GENDER,DOB,ADDRESS,STATEOFORIGIN,SEATNUMBER)
        studentlist.append(ob)
    def display(self,ob):
        print(f'''Firstname =  {ob.firstname}
Middlename =  {ob.middlename}
Surname =  {ob.surname}
Gender =  {ob.gender}
DOB =  {ob.dob}
Address =  {ob.address}
Stateoforigin =  {ob.stateoforigin}
Seatnumber =  {ob.seatnumber}
''')
    def search(self,sn):
        for i in range(len(studentlist)):
            if (studentlist[i].seatnumber ==sn):
                return i
    def update(self,sn,nsn):
        i = obj.search(sn)
        seat = nsn
        studentlist[i].seatnumber = seat
    def delete(self,sn):
        i = obj.search(sn)
        del(studentlist[i])
        
        
studentlist = []

obj = studentmanagementsystem('','','','','','','',0)
		



print("\nOperations used, ")
print("\n1.Accept Student details\n2.Display Student Details\n3.Search Details of a Student\n4.Delete Details of Student\n5.Update Student Details\n6.Exit")

x = input('enter Y as yes and N as no to perform your operation: ')
n = 1
while x =='Y':
    ch = int(input("Enter choice:"))
    if(ch == 1):
        obj.accept(input('Please enter first name:'),input('Please enter middle name:'),input('Please enter Surname name:'),input('Please enter Gender status:'),input('Please enter Date of Birth:'),input('Please enter Address:'),input('Please enter your State of origin:'),int(input('Seat number:')))
                        
    elif(ch == 2):
        print('LIST OF STUDENTS')
        for i in range(len(studentlist)):
            obj.display(studentlist[i])
    elif(ch == 3):
        s = obj.search(int(input('Enter seat number from 1 -5:')))
        obj.display(studentlist[s])
            
    elif(ch == 4):
        obj.update(int(input('Enter seat number from 1 -5:')),8)
        for i in range(len(studentlist)):
            obj.display(studentlist[i])
        
                
    elif(ch == 5):
        obj.delete(int(input('Enter seat number from 1 -5:')))
        print('list after deletion')
        for i in range(len(studentlist)):
            obj.display(studentlist[i])
                    
    else:
        print("Thank You !")
    x = input('enter Y as yes and N as no to perform your operation: ')
    n +=1
# Out:
# Operations used,
#
# 1.Accept Student details
# 2.Display Student Details
# 3.Search Details of a Student
# 4.Delete Details of Student
# 5.Update Student Details
# 6.Exit
# LIST OF STUDENTS
# Firstname =  Ade
# Middlename =  Samuel
# Surname =  Orilabi
# Gender =  Male
# DOB =  17-02-1989
# Address =  No 25 ojukwu street
# Stateoforigin =  Ondo
# Seatnumber =  101
#
# Firstname =  Mary
# Middlename =  Uduak
# Surname =  Akpan
# Gender =  Female
# DOB =  22-02-1990
# Address =  Plot 55 Highway street
# Stateoforigin =  Akwa-Ibom
# Seatnumber =  102

# %%
# This is simplest Patient data management program in python
# Create class "patientmanagementsystem"
# Create a list to add Patient
class patientmanagementsystem:
    def __init__(self,firstname,middlename,surname,gender,dob,address,stateoforigin,hospitalID):
        self.firstname =  firstname
        self.middlename =  middlename
        self.surname =  surname
        self.gender =  gender
        self.dob =  dob
        self.address =  address
        self.stateoforigin =  stateoforigin
        self.hospitalID =  hospitalID
    def accept(self,FIRSTNAME,MIDDLENAME,SURNAME,GENDER,DOB,ADDRESS,STATEOFORIGIN,HOSPITALID):
        ob= patientmanagementsystem(FIRSTNAME,MIDDLENAME,SURNAME,GENDER,DOB,ADDRESS,STATEOFORIGIN,HOSPITALID)
        Plist.append(ob)
    def display(self,ob):
        print(f'''Firstname =  {ob.firstname}
Middlename =  {ob.middlename}
Surname =  {ob.surname}
Gender =  {ob.gender}
DOB =  {ob.dob}
Address =  {ob.address}
Stateoforigin =  {ob.stateoforigin}
HospitalID =  {ob.hospitalID}
''')
    def search(self,hid):
        for i in range(len(Plist)):
            if (Plist[i].hospitalID ==hid):
                return i
    def update(self,hid,nHID):
        i = obj.search(hid)
        seat =nHID
        Plist[i].hospitalID = seat
    def delete(self,hid):
        i = obj.search(hid)
        del(Plist[i])
        
        
Plist = []

obj = patientmanagementsystem('','','','','','','',0)
		



print("\nOperations used, ")
print("\n1.Accept Patient details\n2.Display Patient Details\n3.Search Details of a Patient\n4.Delete Details of Patient\n5.Update Patient Details\n6.Exit")

x = input('enter Y as yes and N as no to perform your operation: ')
n = 1
while x =='Y':
    ch = int(input("Enter choice:"))
    if(ch == 1):
        obj.accept(input('Please enter first name:'),'Ojo','Akinlabi','Male','2000-02-8','St patrick street','Oyo',1)
        obj.accept('Mary','Uju','Okoro','Female','2002-05-8','St Agness street','Abia',2)
        obj.accept('Edidion','Blessing','Akpan','Female','1999-10-26','N0 26 Highway street','Akwa-ibom',3)
        obj.accept('Samuel','Joe','Lawal','Male','2000-08-8','Obasonjo street','Kaduna',4)
        obj.accept('Onomi','Blessing','Peters','Female','1996-02-8','St james street','Benue',5)
                        
    elif(ch == 2):
        print('LIST OF PATIENT')
        for i in range(len(Plist)):
            obj.display(Plist[i])
    elif(ch == 3):
        s = obj.search(int(input('Enter seat number from 1 -5:')))
        obj.display(Plist[s])
            
    elif(ch == 4):
        obj.update(int(input('Enter seat number from 1 -5:')),8)
        for i in range(len(Plist)):
            obj.display(Plist[i])
        
                
    elif(ch == 5):
        obj.delete(int(input('Enter seat number from 1 -5:')))
        print('list after deletion')
        for i in range(len(Plist)):
            obj.display(Plist[i])
                    
    else:
        print("Thank You !")
    x = input('enter Y as yes and N as no to perform your operation: ')
    n +=1

# %%
# import random module
import random

# Print multiline instruction
# performstring concatenation of string
print("Winning Rules of the Rock paper scissor game as follows: \n"
								+"Rock vs paper->paper wins \n"
								+ "Rock vs scissor->Rock wins \n"
								+"paper vs scissor->scissor wins \n")

while True:
	print("Enter choice \n 1 for Rock, \n 2 for paper, and \n 3 for scissor \n")
	
	# take the input from user
	choice = int(input("User turn: "))

	# OR is the short-circuit operator
	# if any one of the condition is true
	# then it return True value
	
	# looping until user enter invalid input
	while choice > 3 or choice < 1:
		choice = int(input("enter valid input: "))
		

	# initialize value of choice_name variable
	# corresponding to the choice value
	if choice == 1:
		choice_name = 'Rock'
	elif choice == 2:
		choice_name = 'paper'
	else:
		choice_name = 'scissor'
		
	# print user choice
	print("user choice is: " + choice_name)
	print("\nNow its computer turn.......")

	# Computer chooses randomly any number
	# among 1 , 2 and 3. Using randint method
	# of random module
	comp_choice = random.randint(1, 3)
	
	# looping until comp_choice value
	# is equal to the choice value
	while comp_choice == choice:
		comp_choice = random.randint(1, 3)

	# initialize value of comp_choice_name
	# variable corresponding to the choice value
	if comp_choice == 1:
		comp_choice_name = 'Rock'
	elif comp_choice == 2:
		comp_choice_name = 'paper'
	else:
		comp_choice_name = 'scissor'
		
	print("Computer choice is: " + comp_choice_name)

	print(choice_name + " V/s " + comp_choice_name)
	#we need to check of a draw
	if choice == comp_choice:
		print("Draw=> ", end = "")
		result = 'Draw'
	
	# condition for winning
		if((choice == 1 and comp_choice == 2) or
		(choice == 2 and comp_choice ==1 )):
			print("paper wins => ", end = "")
			result = "paper"

		elif((choice == 1 and comp_choice == 3) or
			(choice == 3 and comp_choice == 1)):
			print("Rock wins =>", end = "")
			result = "Rock"
		else:
			print("scissor wins =>", end = "")
			result = "scissor"

	# Printing either user or computer wins or draw
	if result == 'Draw':
		print("<== Its a tie ==>")
	if result == choice_name:
		print("<== User wins ==>")
	else:
		print("<== Computer wins ==>")
		
	print("Do you want to play again? (Y/N)")
	ans = input().lower


	# if user input n or N then condition is True
	if ans == 'n':
		break
	
# after coming out of the while loop
# we print thanks for playing
print("\nThanks for playing")
